# %%
install.packages("FactoMineR")
install.packages("factoextra")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(FactoMineR)
library(factoextra)
# Out:
# Loading required package: ggplot2
#
# Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa

# %%
# URL do arquivo no GitHub
url <- "https://raw.githubusercontent.com/elisacastro90/case_bot/master/dados/outputs/dados_analise_correspondencia.csv"

# Baixar o arquivo
download.file(url, destfile = "dados_analise_correspondencia.csv")

# Ler o arquivo CSV
dados <- read.csv("dados_analise_correspondencia.csv")

# Exibir os dados
dados
# Out:
#       X     quadrante         caracteristica
# 1     284   Eficiente (D-R+)  Canal_2
# 2     285   Eficiente (D-R+)  Canal_2
# 3     286   Lucrativo (D+R+)  Canal_2
# 4     287   Estável (D-R-)    Canal_2
# 5     288   Lucrativo (D+R+)  Canal_2
# 6     289   Desafiador (D+R-) Canal_2
# 7     290   Lucrativo (D+R+)  Canal_2
# 8     291   Estável (D-R-)    Canal_2
# 9     292   Estável (D-R-)    Canal_1
# 10    293   Desafiador (D+R-) Canal_1
# 11    294   Estável (D-R-)    Canal_2
# 12    295   Lucrativo (D+R+)  Canal_1
# 13    296   Estável (D-R-)    Canal_1
# 14    297   Desafiador (D+R-) Canal_1
# 15    298   Desafiador (D+R-) Canal_1
# 16    299   Estável (D-R-)    Canal_1
# 17    300   Lucrativo (D+R+)  Canal_1
# 18    301   Desafiador (D+R-) Canal_1
# 19    302   Estável (D-R-)    Canal_1
# 20    303   Desafiador (D+R-) Canal_2
# 21    304   Desafiador (D+R-) Canal_2
# 22    305   Estável (D-R-)    Canal_2
# 23    306   Desafiador (D+R-) Canal_1
# ...

# %%
tabela_contingencia <- table(dados$quadrante, dados$caracteristica)

# %%
CA_case <- CA(tabela_contingencia)
# Out:
# plot without title
